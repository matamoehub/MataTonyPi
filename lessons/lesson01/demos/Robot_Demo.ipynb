# %% [markdown]
# # TonyPi Demo
#
# A tiny placeholder demo for the first lesson bundle.

# %%
from lesson_loader import setup
setup()

from student_robot_v2 import bot
myRobot = bot()
myRobot.say("TonyPi demo time")
myRobot.anim.greet()
