# %% [markdown]
# # Lesson 1 - TonyPi Show Starter
#
# Goal: learn TonyPi's main commands, then build a short robot performance with personality.
#
# ## Feature Goals
#
# In this lesson you will try:
# - speech and greeting
# - head and arm actions
# - poses and body movement
# - vision commands that work on this robot build
# - pickup-style commands
# - a final performance routine

# %% [markdown]
# ## Step 1: Load the lesson robot
#
# Run this first so `myRobot` is ready to use.

# %%
from lesson_header import *

print(myRobot.status())

# %% [markdown]
# ## Step 2: Hello TonyPi
#
# Start with a simple greeting. Change the words if you want.

# %%
myRobot.head.center()
myRobot.say("Hello everyone. I am TonyPi.")
myRobot.anim.wave()
myRobot.anim.greet()

# %% [markdown]
# ## Step 3: Head and arms
#
# TonyPi can look around and use expressive arm poses.

# %%
myRobot.head.look_left()
myRobot.head.look_right()
myRobot.head.look_up()
myRobot.head.look_down()
myRobot.head.center()

myRobot.arms.left_up()
myRobot.arms.right_up()
myRobot.arms.hands_up()
myRobot.arms.open()
myRobot.arms.close()
myRobot.arms.center()

# %% [markdown]
# ## Step 4: Poses and movement
#
# TonyPi can change poses, walk, turn, sidestep, and stop.

# %%
myRobot.pose.ready()
myRobot.pose.bow()
myRobot.stand()
myRobot.motion.walk_forward(steps=1)
myRobot.motion.walk_backward(steps=1)
myRobot.motion.turn_left(steps=1)
myRobot.motion.turn_right(steps=1)
myRobot.motion.step_left(steps=1)
myRobot.motion.step_right(steps=1)
myRobot.motion.stop()
myRobot.sit()
myRobot.stand()

# %% [markdown]
# ## Step 5: Vision explorer
#
# These commands use the current TonyPi vision helpers. Color, face, tag, snapshot, and hand-recognition are available on the classroom robot build.

# %%
myRobot.head.center()
color_result = myRobot.vision.find_color("blue")
face_result = myRobot.vision.find_face()
tag_result = myRobot.vision.find_tag(1)
hand_result = myRobot.vision.recognize_hands(show=True)

print(color_result.to_dict())
print(face_result.to_dict())
print(tag_result.to_dict())
print(hand_result)

myRobot.vision.track_color("blue")
myRobot.vision.track_face()
print(myRobot.vision.scan_for("blue"))
myRobot.vision.snapshot()

# %% [markdown]
# ## Step 6: Pickup routine
#
# These commands introduce the pickup flow that later lessons can build on.

# %%
myRobot.pickup.approach_object("block")
myRobot.pickup.pick_up("block")
myRobot.pickup.grab()
myRobot.pickup.carry()
myRobot.pickup.place_down()
myRobot.pickup.release()

# %% [markdown]
# ## Performance Plan
#
# Build a mini show where TonyPi:
# 1. Greets the audience
# 2. Looks around the room
# 3. Walks and turns with style
# 4. Uses the camera to check for a blue target
# 5. Finishes with a celebration

# %%
myRobot.say("Watch my TonyPi show.")
myRobot.anim.greet()
myRobot.head.scan()
myRobot.motion.walk_forward(steps=1)
myRobot.motion.turn_right(steps=1)
print(myRobot.vision.scan_for("blue"))
myRobot.anim.think()
myRobot.pickup.approach_object("cube")
myRobot.anim.celebrate()
myRobot.voice.celebrate()
myRobot.home()

# %% [markdown]
# ## Your Turn
#
# Change this final routine so it feels like your own robot character.
#
# Ideas:
# - make TonyPi sound brave, funny, or dramatic
# - add more head and arm actions
# - use different movement commands
# - check for a different supported target color
# - create a bigger ending pose
#
# # Challenge: edit this routine and make it your own.

# %%
myRobot.say("Hello. I made my own TonyPi routine.")

# Add more actions here
myRobot.anim.wave()
myRobot.head.look_left()
myRobot.motion.turn_left(steps=1)

myRobot.home()
