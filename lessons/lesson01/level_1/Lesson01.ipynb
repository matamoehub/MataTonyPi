# %% [markdown]
# # Lesson 1 - Hello TonyPi
#
# Start with the central V2 library.

# %%
from lesson_header import *

myRobot.say("Hello everyone")
myRobot.anim.wave()
myRobot.head.look_left()
myRobot.head.look_right()
