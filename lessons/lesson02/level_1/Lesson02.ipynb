# %% [markdown]
# # Lesson 2 - Talking, Head Movement, and Gestures
#
# Use speech, head movement, and simple gestures to make TonyPi expressive and responsive.

# %% [markdown]
# ## Setup
# Run the next cell first to initialize `myRobot`.

# %%
from lesson_header import *
print(myRobot.status())

# %% [markdown]
# ## Activity 1

# %%
myRobot.say("Hello, I am TonyPi!")

# %% [markdown]
# ## Activity 2

# %%
myRobot.head.look_left(); myRobot.head.look_right(); myRobot.head.center()

# %% [markdown]
# ## Activity 3

# %%
myRobot.head.nod(); myRobot.head.shake()

# %% [markdown]
# ## Activity 4

# %%
myRobot.arms.hands_up(); myRobot.anim.greet()
