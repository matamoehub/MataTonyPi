# %% [markdown]
# # Lesson 3 - Action Groups and Performances
#
# Use prebuilt action groups and speech to choreograph short performances.

# %% [markdown]
# ## Setup
# Run the next cell first to initialize `myRobot`.

# %%
from lesson_header import *
print(myRobot.status())

# %% [markdown]
# ## Activity 1

# %%
print(myRobot.anim.list_action_groups()[:12])

# %% [markdown]
# ## Activity 2

# %%
myRobot.anim.wave(); myRobot.say("Welcome to our show!")

# %% [markdown]
# ## Activity 3

# %%
myRobot.anim.dance(); myRobot.anim.celebrate()

# %% [markdown]
# ## Activity 4

# %%
myRobot.anim.run("bow")
