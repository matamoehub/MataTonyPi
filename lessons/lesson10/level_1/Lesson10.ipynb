# %% [markdown]
# # Lesson 10 - Tag Detection and Tag Actions
#
# Detect AprilTags and trigger different actions per tag id.

# %% [markdown]
# ## Setup
# Run the next cell first to initialize `myRobot`.

# %%
from lesson_header import *
print(myRobot.status())

# %% [markdown]
# ## Activity 1

# %%
for tag_id in [1, 2, 3]:
    tag = myRobot.vision.find_tag(tag_id)
    print(tag.to_dict())

# %% [markdown]
# ## Activity 2

# %%
tag = myRobot.vision.find_tag(1)
if tag.found:
    myRobot.say("Tag one detected")
    myRobot.anim.wave()
else:
    myRobot.say("No tag one")
