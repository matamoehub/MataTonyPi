# %% [markdown]
# # Lesson 11 - Face Detect and Greeting
#
# Detect faces and respond with greetings, gestures, and tracking behavior.

# %% [markdown]
# ## Setup
# Run the next cell first to initialize `myRobot`.

# %%
from lesson_header import *
print(myRobot.status())

# %% [markdown]
# ## Activity 1

# %%
face = myRobot.vision.find_face()
print(face.to_dict())

# %% [markdown]
# ## Activity 2

# %%
if face.found:
    myRobot.say("Hello there!")
    myRobot.anim.greet()
else:
    myRobot.say("I do not see a face yet")
    myRobot.head.scan()
