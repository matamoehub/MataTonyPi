# %% [markdown]
# # Lesson 12 - Pickup and Intelligent Transport
#
# Combine detection, approach, pickup, carry, and place-down in one transport flow.

# %% [markdown]
# ## Setup
# Run the next cell first to initialize `myRobot`.

# %%
from lesson_header import *
print(myRobot.status())

# %% [markdown]
# ## Activity 1

# %%
myRobot.pickup.approach_object("block")

# %% [markdown]
# ## Activity 2

# %%
myRobot.pickup.pick_up("block")
myRobot.pickup.carry()

# %% [markdown]
# ## Activity 3

# %%
destination = myRobot.vision.find_tag(2)
print(destination.to_dict())
if destination.found:
    myRobot.say("Destination found")
    myRobot.pickup.place_down()
else:
    myRobot.say("Searching for destination tag")
